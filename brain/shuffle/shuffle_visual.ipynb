# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scanpy as sc
from scipy.stats import zscore

from rich import print

# Set SVG font type to 'none' to keep text as text in SVG files
plt.rcParams["svg.fonttype"] = "none"
# Out:
# /home/nathanlevy/mambaforge/envs/scvi/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/nathanlevy/mambaforge/envs/scvi/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/nathanlevy/mambaforge/envs/scvi/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/nathanlevy/mambaforge/envs/scvi/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# ...

# %%
FIGURES_FOLDER = (
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures_journal"
)

# %% [markdown]
# # Histogram/QQPlot across cells

# %% [markdown]
# Shuffled

# %%
clisi_oligo = np.load("figures/cLISI_oligodendrocyte.npy")  # BANKSY
clisi_astro = np.load("figures/cLISI_astrocyte.npy")
clisi_gluta = np.load("figures/cLISI_glutamatergic.npy")
clisi_endo = np.load("figures/cLISI_endothelial.npy")
clisi_micro = np.load("figures/cLISI_microglial.npy")
clisi_peri = np.load("figures/cLISI_pericyte.npy")
clisi_opc = np.load("figures/cLISI_oligodendrocyte_precursor.npy")
clisi_gaba = np.load("figures/cLISI_GABAergic.npy")

clisi_astro_nichevi = np.load(
    "../niche-VI-experiments/merfish_brain_atlas_shuffle/figures/nichevi/cLISI_astrocyte.npy"
)
clisi_astro_scanvi = np.load(
    "../niche-VI-experiments/merfish_brain_atlas_shuffle/figures/scanvi/cLISI_astrocyte.npy"
)

clisi_oligo_nichevi = np.load(
    "../niche-VI-experiments/merfish_brain_atlas_shuffle/figures/nichevi/cLISI_oligodendrocyte.npy"
)
clisi_oligo_scanvi = np.load(
    "../niche-VI-experiments/merfish_brain_atlas_shuffle/figures/scanvi/cLISI_oligodendrocyte.npy"
)

clisi_gluta_nichevi = np.load(
    "../niche-VI-experiments/merfish_brain_atlas_shuffle/figures/nichevi/cLISI_glutamatergic.npy"
)
clisi_gluta_scanvi = np.load(
    "../niche-VI-experiments/merfish_brain_atlas_shuffle/figures/scanvi/cLISI_glutamatergic.npy"
)

clisi_endo_nichevi = np.load(
    "../niche-VI-experiments/merfish_brain_atlas_shuffle/figures/nichevi/cLISI_endothelial.npy"
)
clisi_endo_scanvi = np.load(
    "../niche-VI-experiments/merfish_brain_atlas_shuffle/figures/scanvi/cLISI_endothelial.npy"
)

clisi_micro_nichevi = np.load(
    "../niche-VI-experiments/merfish_brain_atlas_shuffle/figures/nichevi/cLISI_microglial.npy"
)
clisi_micro_scanvi = np.load(
    "../niche-VI-experiments/merfish_brain_atlas_shuffle/figures/scanvi/cLISI_microglial.npy"
)

clisi_peri_nichevi = np.load(
    "../niche-VI-experiments/merfish_brain_atlas_shuffle/figures/nichevi/cLISI_pericyte.npy"
)
clisi_peri_scanvi = np.load(
    "../niche-VI-experiments/merfish_brain_atlas_shuffle/figures/scanvi/cLISI_pericyte.npy"
)

clisi_opc_nichevi = np.load(
    "../niche-VI-experiments/merfish_brain_atlas_shuffle/figures/nichevi/cLISI_oligodendrocyte_precursor.npy"
)
clisi_opc_scanvi = np.load(
    "../niche-VI-experiments/merfish_brain_atlas_shuffle/figures/scanvi/cLISI_oligodendrocyte_precursor.npy"
)

clisi_gaba_nichevi = np.load(
    "../niche-VI-experiments/merfish_brain_atlas_shuffle/figures/nichevi/cLISI_GABAergic.npy"
)
clisi_gaba_scanvi = np.load(
    "../niche-VI-experiments/merfish_brain_atlas_shuffle/figures/scanvi/cLISI_GABAergic.npy"
)


np.median(clisi_astro), np.median(clisi_astro_scanvi)
# Out:
# (0.8920133, 0.5608634)

# %% [markdown]
# Original

# %%
clisi_astro_nichevi_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_astrocyte_s10_scanvi_lr0.0005_poisson_X_nicheVI.npy"
)
clisi_astro_scanvi_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_astrocyte_X_scanvi.npy"
)

clisi_astro_banksy_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_astrocyte_X_banksy_02_harmony.npy"
)


clisi_oligo_nichevi_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_oligodendrocyte_s10_scanvi_lr0.0005_poisson_X_nicheVI.npy"
)
clisi_oligo_scanvi_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_oligodendrocyte_X_scanvi.npy"
)

clisi_oligo_banksy_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_oligodendrocyte_X_banksy_02_harmony.npy"
)


clisi_gluta_nichevi_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_glutamatergic_s10_scanvi_lr0.0005_poisson_X_nicheVI.npy"
)
clisi_gluta_scanvi_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_glutamatergic_X_scanvi.npy"
)

clisi_gluta_banksy_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_glutamatergic_X_banksy_02_harmony.npy"
)

clisi_endo_nichevi_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_endothelial_s10_scanvi_lr0.0005_poisson_X_nicheVI.npy"
)
clisi_endo_scanvi_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_endothelial_X_scanvi.npy"
)
clisi_endo_banksy_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_endothelial_X_banksy_02_harmony.npy"
)

clisi_micro_nichevi_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_microglial_s10_scanvi_lr0.0005_poisson_X_nicheVI.npy"
)
clisi_micro_scanvi_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_microglial_X_scanvi.npy"
)
clisi_micro_banksy_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_microglial_X_banksy_02_harmony.npy"
)

clisi_peri_nichevi_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_pericyte_s10_scanvi_lr0.0005_poisson_X_nicheVI.npy"
)
clisi_peri_scanvi_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_pericyte_X_scanvi.npy"
)
clisi_peri_banksy_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_pericyte_X_banksy_02_harmony.npy"
)

clisi_opc_nichevi_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_oligodendrocyte_precursor_s10_scanvi_lr0.0005_poisson_X_nicheVI.npy"
)
clisi_opc_scanvi_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_oligodendrocyte_precursor_X_scanvi.npy"
)
clisi_opc_banksy_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_oligodendrocyte_precursor_X_banksy_02_harmony.npy"
)

clisi_gaba_nichevi_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_GABAergic_s10_scanvi_lr0.0005_poisson_X_nicheVI.npy"
)
clisi_gaba_scanvi_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_GABAergic_X_scanvi.npy"
)
clisi_gaba_banksy_orig = np.load(
    "/home/nathanlevy/sda/niche-VI-experiments/merfish_brain_atlas/figures/cLISI/cLISI_GABAergic_X_banksy_02_harmony.npy"
)

# %%
BINS = 50

dict_of_orig = {
    "Glutamatergic": [
        clisi_gluta_nichevi_orig,
        clisi_gluta_scanvi_orig,
        clisi_gluta_banksy_orig,
        "gluta",
    ],
    "Oligodendrocyte": [
        clisi_oligo_nichevi_orig,
        clisi_oligo_scanvi_orig,
        clisi_oligo_banksy_orig,
        "oligo",
    ],
    "Astrocyte": [
        clisi_astro_nichevi_orig,
        clisi_astro_scanvi_orig,
        clisi_astro_banksy_orig,
        "astro",
    ],
    "Endothelial": [
        clisi_endo_nichevi_orig,
        clisi_endo_scanvi_orig,
        clisi_endo_banksy_orig,
        "endo",
    ],
    "Microglial": [
        clisi_micro_nichevi_orig,
        clisi_micro_scanvi_orig,
        clisi_micro_banksy_orig,
        "micro",
    ],
    "Pericyte": [
        clisi_peri_nichevi_orig,
        clisi_peri_scanvi_orig,
        clisi_peri_banksy_orig,
        "peri",
    ],
    "Oligodendrocyte precursor": [
        clisi_opc_nichevi_orig,
        clisi_opc_scanvi_orig,
        clisi_opc_banksy_orig,
        "opc",
    ],
    "GABAergic": [
        clisi_gaba_nichevi_orig,
        clisi_gaba_scanvi_orig,
        clisi_gaba_banksy_orig,
        "gaba",
    ],
}

key_to_plot = list(dict_of_orig.keys())[7]
# Plot the two histograms on the same figure
plt.figure(figsize=(6, 4))
# Histogram for the second series 'b'
plt.hist(
    dict_of_orig[key_to_plot][1], bins=BINS, alpha=0.5, label="SCANVI", color="green"
)

# Histogram for the first series 'a'
plt.hist(
    dict_of_orig[key_to_plot][2],
    bins=BINS,
    alpha=0.5,
    label="Banksy",
    color="blue",
)

plt.hist(
    dict_of_orig[key_to_plot][0], bins=BINS, alpha=0.5, label="NICHEVI", color="red"
)

# Add labels and title
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title(f"Overlayed Histograms of {key_to_plot} cLISI - Original")

# Add a legend to differentiate the two series
plt.legend()

# plt.savefig(
#     f"{FIGURES_FOLDER}/{dict_of_orig[key_to_plot][-1]}_cLISI_orig.png", dpi=1000
# )
# plt.savefig(
#     f"{FIGURES_FOLDER}/{dict_of_orig[key_to_plot][-1]}_cLISI_orig.svg", dpi=1000
# )

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define unique color and linestyle for each method
styles = {
    "SCANVI": {"color": "green", "linestyle": "--"},
    "BANKSY": {"color": "blue", "linestyle": (0, (1, 2))},
    "NICHEVI": {"color": "red", "linestyle": (0, (1, 1, 4, 1))},
}

linewidth = 2.5
cumulative = True

plt.figure(figsize=(6, 4))

# Plot each KDE with a distinct style
sns.kdeplot(
    dict_of_orig[key_to_plot][1],
    label="SCANVI",
    color=styles["SCANVI"]["color"],
    linestyle=styles["SCANVI"]["linestyle"],
    linewidth=linewidth,
    common_norm=True,
    cumulative=cumulative,
)

sns.kdeplot(
    dict_of_orig[key_to_plot][2],
    label="BANKSY",
    color=styles["BANKSY"]["color"],
    linestyle=styles["BANKSY"]["linestyle"],
    linewidth=linewidth,
    common_norm=True,
    cumulative=cumulative,
)

sns.kdeplot(
    dict_of_orig[key_to_plot][0],
    label="NICHEVI",
    color=styles["NICHEVI"]["color"],
    linestyle=styles["NICHEVI"]["linestyle"],
    linewidth=linewidth,
    common_norm=True,
    cumulative=cumulative,
)

plt.xlabel("cLISI values")
plt.ylabel("Density")
plt.title(f"KDE of {key_to_plot} cLISI - Original")
plt.legend()
plt.tight_layout()

plt.savefig(
    f"{FIGURES_FOLDER}/{dict_of_orig[key_to_plot][-1]}_cLISI_orig_cdf.png", dpi=1000
)
plt.savefig(
    f"{FIGURES_FOLDER}/{dict_of_orig[key_to_plot][-1]}_cLISI_orig_cdf.svg", dpi=1000
)

plt.show()
# Out:
# /home/nathanlevy/mambaforge/envs/scvi/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/nathanlevy/mambaforge/envs/scvi/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/nathanlevy/mambaforge/envs/scvi/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dict_after_shuffle = {
    "Glutamatergic": [
        clisi_gluta_nichevi,
        clisi_gluta_scanvi,
        clisi_gluta,
        "gluta",
    ],
    "Oligodendrocyte": [
        clisi_oligo_nichevi,
        clisi_oligo_scanvi,
        clisi_oligo,
        "oligo",
    ],
    "Astrocyte": [
        clisi_astro_nichevi,
        clisi_astro_scanvi,
        clisi_astro,
        "astro",
    ],
    "Endothelial": [
        clisi_endo_nichevi,
        clisi_endo_scanvi,
        clisi_endo,
        "endo",
    ],
    "Microglial": [
        clisi_micro_nichevi,
        clisi_micro_scanvi,
        clisi_micro,
        "micro",
    ],
    "Pericyte": [
        clisi_peri_nichevi,
        clisi_peri_scanvi,
        clisi_peri,
        "peri",
    ],
    "Oligodendrocyte precursor": [
        clisi_opc_nichevi,
        clisi_opc_scanvi,
        clisi_opc,
        "opc",
    ],
    "GABAergic": [
        clisi_gaba_nichevi,
        clisi_gaba_scanvi,
        clisi_gaba,
        "gaba",
    ],
}

# key_to_plot = "Endothelial"

# Plot the two histograms on the same figure
plt.figure(figsize=(6, 4))
# Histogram for the second series 'b'
plt.hist(
    dict_after_shuffle[key_to_plot][1],
    bins=BINS,
    alpha=0.5,
    label="SCANVI",
    color="green",
)

# Histogram for the first series 'a'
plt.hist(
    dict_after_shuffle[key_to_plot][2],
    bins=BINS,
    alpha=0.5,
    label="Banksy",
    color="blue",
)

plt.hist(
    dict_after_shuffle[key_to_plot][0],
    bins=BINS,
    alpha=0.5,
    label="NICHEVI",
    color="red",
)

# Add labels and title
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title(f"Overlayed Histograms of {key_to_plot} cLISI - After Shuffle")

# Add a legend to differentiate the two series
plt.legend()

# plt.savefig(
#     f"{FIGURES_FOLDER}/{dict_after_shuffle[key_to_plot][-1]}_cLISI.png", dpi=1000
# )
# plt.savefig(
#     f"{FIGURES_FOLDER}/{dict_after_shuffle[key_to_plot][-1]}_cLISI.svg", dpi=1000
# )

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define unique color and linestyle for each method
styles = {
    "SCANVI": {"color": "green", "linestyle": "--"},
    "BANKSY": {"color": "blue", "linestyle": (0, (1, 2))},
    "NICHEVI": {"color": "red", "linestyle": (0, (1, 1, 4, 1))},
}

plt.figure(figsize=(6, 4))

# Plot each KDE with a distinct style
sns.kdeplot(
    dict_after_shuffle[key_to_plot][1],
    label="SCANVI",
    color=styles["SCANVI"]["color"],
    linestyle=styles["SCANVI"]["linestyle"],
    linewidth=linewidth,
    common_norm=True,
    cumulative=cumulative,
)

sns.kdeplot(
    dict_after_shuffle[key_to_plot][2],
    label="BANKSY",
    color=styles["BANKSY"]["color"],
    linestyle=styles["BANKSY"]["linestyle"],
    linewidth=linewidth,
    common_norm=True,
    cumulative=cumulative,
)

sns.kdeplot(
    dict_after_shuffle[key_to_plot][0],
    label="NICHEVI",
    color=styles["NICHEVI"]["color"],
    linestyle=styles["NICHEVI"]["linestyle"],
    linewidth=linewidth,
    common_norm=True,
    cumulative=cumulative,
)

plt.xlabel("cLISI values")
plt.ylabel("Density")
plt.title(f"KDE of {key_to_plot} cLISI - After Shuffle")
plt.legend()
plt.tight_layout()

plt.savefig(
    f"{FIGURES_FOLDER}/{dict_after_shuffle[key_to_plot][-1]}_cLISI_cdf.png", dpi=1000
)
plt.savefig(
    f"{FIGURES_FOLDER}/{dict_after_shuffle[key_to_plot][-1]}_cLISI_cdf.svg", dpi=1000
)

plt.show()
# Out:
# /home/nathanlevy/mambaforge/envs/scvi/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/nathanlevy/mambaforge/envs/scvi/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/nathanlevy/mambaforge/envs/scvi/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import gaussian_kde

plt.figure(figsize=(6, 4))

# Compute x-range for KDE
all_values = np.concatenate([dict_after_shuffle[key_to_plot][i] for i in range(3)])
x_vals = np.linspace(all_values.min(), all_values.max(), 300)

# KDE for NICHEVI (standard line)
nichevi = gaussian_kde(dict_after_shuffle[key_to_plot][0])
plt.plot(
    x_vals,
    nichevi(x_vals),
    label="NICHEVI",
    color="red",
    linestyle=(0, (1, 2)),  # short dashes
    linewidth=2,
)

# KDE for BANKSY (line with square-like dash)
banksy = gaussian_kde(dict_after_shuffle[key_to_plot][2])
plt.plot(
    x_vals,
    banksy(x_vals),
    label="BANKSY",
    color="blue",
    linestyle=(0, (1, 1, 4, 1)),  # custom dash pattern
    linewidth=2,
)

# KDE for SCANVI (circles as marker)
scanvi = gaussian_kde(dict_after_shuffle[key_to_plot][1])
y_vals_scanvi = scanvi(x_vals)
plt.plot(
    x_vals,
    y_vals_scanvi,
    label="SCANVI",
    color="green",
    linestyle="None",
    marker="o",
    markersize=2,
    markevery=3,
)

# Labels, legend, and export
plt.xlabel("cLISI values")
plt.ylabel("Density")
plt.title(f"KDE of {key_to_plot} cLISI - After Shuffle")
plt.legend()
plt.tight_layout()

# plt.savefig(
#     f"{FIGURES_FOLDER}/{dict_after_shuffle[key_to_plot][-1]}_cLISI_cdf.png", dpi=1000
# )
# plt.savefig(
#     f"{FIGURES_FOLDER}/{dict_after_shuffle[key_to_plot][-1]}_cLISI_cdf.svg", dpi=1000
# )

plt.show()

# %%
BINS = 50

# Plot the two histograms on the same figure
plt.figure(figsize=(6, 4))

plt.hist(clisi_oligo_scanvi, bins=BINS, alpha=0.5, label="SCANVI", color="green")


# Histogram for the first series 'a'
plt.hist(
    clisi_oligo,
    bins=BINS,
    alpha=0.5,
    label="Banksy",
    color="blue",
)

# Histogram for the second series 'b'
plt.hist(clisi_oligo_nichevi, bins=BINS, alpha=0.5, label="NICHEVI", color="red")

# Add labels and title
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Overlayed Histograms of Oligodendrocytes")

# Add a legend to differentiate the two series
plt.legend()

plt.savefig(f"{FIGURES_FOLDER}/oligo_cLISI.png", dpi=1000)
plt.savefig(f"{FIGURES_FOLDER}/oligo_cLISI.svg", dpi=1000)

# Display the plot
plt.show()

# %%
# Plot the two histograms on the same figure
plt.figure(figsize=(6, 4))


plt.hist(clisi_gluta_scanvi, bins=50, alpha=0.5, label="SCANVI", color="green")

# Histogram for the first series 'a'
plt.hist(
    clisi_gluta,
    bins=50,
    alpha=0.5,
    label="Banksy",
    color="blue",
)

# Histogram for the second series 'b'
plt.hist(clisi_gluta_nichevi, bins=50, alpha=0.5, label="NICHEVI", color="red")

# Add labels and title
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Overlayed Histograms Glutamatergic neurons")

# Add a legend to differentiate the two series
plt.legend()

plt.savefig(f"{FIGURES_FOLDER}/gluta_cLISI.png", dpi=1000)
plt.savefig(f"{FIGURES_FOLDER}/gluta_cLISI.svg", dpi=1000)

# Display the plot
plt.show()
